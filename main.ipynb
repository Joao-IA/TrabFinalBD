# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
db_host = '104.198.65.25'
db_user = 'joao'
db_password = '123456'
db_name = 'TRABFINAL'

conn = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}')

# %%
# Definindo as consultas SQL para criar as tabelas
create_table_queries = [
    '''
    CREATE TABLE Clientes (
        ClienteID INTEGER PRIMARY KEY,
        Nome TEXT,
        Endereço_de_Entrega TEXT,
        Telefone TEXT,
        Email TEXT
    )
    ''',
    '''
    CREATE TABLE Produtos (
        ProdutoID INTEGER PRIMARY KEY,
        Nome_do_Produto TEXT,
        Descrição TEXT,
        Peso REAL,
        Dimensões TEXT
    )
    ''',
    '''
    CREATE TABLE Pedidos (
        PedidoID INTEGER PRIMARY KEY,
        ClienteID INTEGER,
        Data_do_Pedido TEXT,
        Status TEXT,
        FOREIGN KEY (ClienteID) REFERENCES Clientes(ClienteID)
    )
    ''',
    '''
    CREATE TABLE Entregas (
        EntregaID INTEGER PRIMARY KEY,
        PedidoID INTEGER,
        VeículoID INTEGER,
        DataHoraInicio TEXT,
        DataHoraFim TEXT,
        Status_da_Entrega TEXT,
        FOREIGN KEY (PedidoID) REFERENCES Pedidos(PedidoID),
        FOREIGN KEY (VeículoID) REFERENCES Veículos(VeículoID)
    )
    ''',
    '''
    CREATE TABLE Veículos (
        VeículoID INTEGER PRIMARY KEY,
        Tipo_de_Veículo TEXT,
        Capacidade REAL,
        Localização_Atual TEXT
    )
    ''',
    '''
    CREATE TABLE Motoristas (
        MotoristaID INTEGER PRIMARY KEY,
        Nome TEXT,
        CNH TEXT,
        VeículoID INTEGER,
        FOREIGN KEY (VeículoID) REFERENCES Veículos(VeículoID)
    )
    '''
]

# Conectando ao banco de dados e criando as tabelas
with conn.connect() as connection:
    for query in create_table_queries:
        connection.execute(query)

print("Tabelas criadas com sucesso.")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/BD/lib/python3.12/site-packages/pymysql/connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File ~/anaconda3/envs/BD/lib/python3.12/socket.py:853, in create_connection(address, timeout, source_address, all_errors)
#     852 if not all_errors:
# --> 853     raise exceptions[0]
#     854 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/anaconda3/envs/BD/lib/python3.12/socket.py:838, in create_connection(address, timeout, source_address, all_errors)
#     837     sock.bind(source_address)
# --> 838 sock.connect(sa)
#     839 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# ...
